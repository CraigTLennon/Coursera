# %% [markdown]
# File locations
# '/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3.cfg'
# '/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3.weights'
# '/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/coco.names'

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import BatchNormalization, Conv2D, \
    Input, ZeroPadding2D, LeakyReLU, UpSampling2D
import numpy as np


def parse_cfg(cfgfile):
    with open(cfgfile, 'r') as file:
        lines = [line.rstrip('\n') for line in file if line != '\n' and line[0] != '#']
    holder = {}
    blocks = []
    for line in lines:
        if line[0] == '[':
            line = 'type=' + line[1:-1].rstrip()
            if len(holder) != 0:
                blocks.append(holder)
                holder = {}
        key, value = line.split("=")
        holder[key.rstrip()] = value.lstrip()
    blocks.append(holder)
    return blocks

def YOLOv3Net(cfgfile, model_size, num_classes):
    blocks = parse_cfg(cfgfile)
    outputs = {}
    output_filters = []
    filters = []
    out_pred = []
    scale = 0
    inputs = input_image = Input(shape=model_size)
    inputs = inputs / 255.0
    for i, block in enumerate(blocks[1:]):
        # If it is a convolutional layer
        if (block["type"] == "convolutional"):
            activation = block["activation"]
            filters = int(block["filters"])
            kernel_size = int(block["size"])
            strides = int(block["stride"])
            if strides > 1:
                inputs = ZeroPadding2D(((1, 0), (1, 0)))(inputs)
            inputs = Conv2D(filters,
                            kernel_size,
                            strides=strides,
                            padding='valid' if strides > 1 else 'same',
                            name='conv_' + str(i),
                            use_bias=False if ("batch_normalize" in block) else True)(inputs)
            if "batch_normalize" in block:
                inputs = BatchNormalization(name='bnorm_' + str(i))(inputs)
            #if activation == "leaky":
                inputs = LeakyReLU(alpha=0.1, name='leaky_' + str(i))(inputs)
        elif (block["type"] == "upsample"):
            stride = int(block["stride"])
            inputs = UpSampling2D(stride)(inputs)
        # If it is a route layer
        elif (block["type"] == "route"):
            block["layers"] = block["layers"].split(',')
            start = int(block["layers"][0])
            if len(block["layers"]) > 1:
                end = int(block["layers"][1]) - i
                filters = output_filters[i + start] + output_filters[end]  # Index negatif :end - index
                inputs = tf.concat([outputs[i + start], outputs[i + end]], axis=-1)
            else:
                filters = output_filters[i + start]
                inputs = outputs[i + start]
        elif block["type"] == "shortcut":
            from_ = int(block["from"])
            inputs = outputs[i - 1] + outputs[i + from_]
        # Yolo detection layer
        elif block["type"] == "yolo":
            mask = block["mask"].split(",")
            mask = [int(x) for x in mask]
            anchors = block["anchors"].split(",")
            anchors = [int(a) for a in anchors]
            anchors = [(anchors[i], anchors[i + 1]) for i in range(0, len(anchors), 2)]
            anchors = [anchors[i] for i in mask]
            n_anchors = len(anchors)
            out_shape = inputs.get_shape().as_list()
            inputs = tf.reshape(inputs, [-1, n_anchors * out_shape[1] * out_shape[2], \
           5 + num_classes])
            box_centers = inputs[:, :, 0:2]
            box_shapes = inputs[:, :, 2:4]
            confidence = inputs[:, :, 4:5]
            classes = inputs[:, :, 5:num_classes + 5]
            box_centers = tf.sigmoid(box_centers)
            confidence = tf.sigmoid(confidence)
            classes = tf.sigmoid(classes)
            anchors = tf.tile(anchors, [out_shape[1] * out_shape[2], 1])
            box_shapes = tf.exp(box_shapes) * tf.cast(anchors, dtype=tf.float32)
            x = tf.range(out_shape[1], dtype=tf.float32)
            y = tf.range(out_shape[2], dtype=tf.float32)
            cx, cy = tf.meshgrid(x, y)
            cx = tf.reshape(cx, (-1, 1))
            cy = tf.reshape(cy, (-1, 1))
            cxy = tf.concat([cx, cy], axis=-1)
            cxy = tf.tile(cxy, [1, n_anchors])
            cxy = tf.reshape(cxy, [1, -1, 2])
            strides = (input_image.shape[1] // out_shape[1], \
                       input_image.shape[2] // out_shape[2])
            box_centers = (box_centers + cxy) * strides
            prediction = tf.concat([box_centers, box_shapes, confidence, classes], axis=-1)
            if scale:
                out_pred = tf.concat([out_pred, prediction], axis=1)
            else:
                out_pred = prediction
                scale = 1
        outputs[i] = inputs
        output_filters.append(filters)
    model = Model(input_image, out_pred)
    model.summary()
    return model

# %%
def load_weights(model,cfgfile,weightfile):
    # Open the weights file
    fp = open(weightfile, "rb")
    # Skip 5 header values
    np.fromfile(fp, dtype=np.int32, count=5)
    # The rest of the values are the weights
    blocks = parse_cfg(cfgfile)
    for i, block in enumerate(blocks[1:]):
        if (block["type"] == "convolutional"):
            conv_layer = model.get_layer('conv_' + str(i))
            print("layer: ",i+1,conv_layer)
            filters = conv_layer.filters
            k_size = conv_layer.kernel_size[0]
            in_dim = conv_layer.input_shape[-1]
            if "batch_normalize" in block:
                norm_layer = model.get_layer('bnorm_' + str(i))
                print("layer: ",i+1,norm_layer)
                size = np.prod(norm_layer.get_weights()[0].shape)
                bn_weights = np.fromfile(fp, dtype=np.float32, count=4 * filters)
                # tf [gamma, beta, mean, variance]
                bn_weights = bn_weights.reshape((4, filters))[[1, 0, 2, 3]]
            else:
                conv_bias = np.fromfile(fp, dtype=np.float32, count=filters)
            # darknet shape (out_dim, in_dim, height, width)
            conv_shape = (filters, in_dim, k_size, k_size)
            conv_weights = np.fromfile(
                fp, dtype=np.float32, count=np.product(conv_shape))
            # tf shape (height, width, in_dim, out_dim)
            conv_weights = conv_weights.reshape(
                conv_shape).transpose([2, 3, 1, 0])
            if "batch_normalize" in block:
                norm_layer.set_weights(bn_weights)
                conv_layer.set_weights([conv_weights])
            else:
                conv_layer.set_weights([conv_weights, conv_bias])
    assert len(fp.read()) == 0, 'failed to read all data'
    fp.close()

# %%
cfg='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3.cfg'
wts='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3.weights'
class_names='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/coco.names'
wt_destination='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3_tf_weights.tf'
def save_weights():
    weightfile = wts
    cfgfile = cfg
    model_size = (416, 416, 3)
    num_classes = 80
    model=YOLOv3Net(cfgfile,model_size,num_classes)
    load_weights(model,cfgfile,weightfile)
    try:
        model.save_weights(wt_destination)
        print('\nThe file \'yolov3_weights.tf\' has been saved successfully.')
    except IOError:
        print("Couldn't write the file \'yolov3_weights.tf\'.")

# %%
cfg='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3.cfg'
wts='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3.weights'
class_names='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/coco.names'
model_destination='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3_model'
def save_keras_model():
    weightfile = wts
    cfgfile = cfg
    model_size = (416, 416, 3)
    num_classes = 80
    model=YOLOv3Net(cfgfile,model_size,num_classes)
    load_weights(model,cfgfile,weightfile)
    try:
        model.save(model_destination)
        print('\nThe model \'yolov3\' has been saved successfully.')
    except IOError:
        print("Couldn't write the model file")
save_keras_model()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# tf.math.truediv_6 (TFOpLambda)  (None, 416, 416, 3)  0           input_7[0][0]
# __________________________________________________________________________________________________
# conv_0 (Conv2D)                 (None, 416, 416, 32) 864         tf.math.truediv_6[0][0]
# __________________________________________________________________________________________________
# bnorm_0 (BatchNormalization)    (None, 416, 416, 32) 128         conv_0[0][0]
# __________________________________________________________________________________________________
# leaky_0 (LeakyReLU)             (None, 416, 416, 32) 0           bnorm_0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 417, 417, 32) 0           leaky_0[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 208, 208, 64) 18432       zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# bnorm_1 (BatchNormalization)    (None, 208, 208, 64) 256         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_1 (LeakyReLU)             (None, 208, 208, 64) 0           bnorm_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 208, 208, 32) 2048        leaky_1[0][0]
# __________________________________________________________________________________________________
# bnorm_2 (BatchNormalization)    (None, 208, 208, 32) 128         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_2 (LeakyReLU)             (None, 208, 208, 32) 0           bnorm_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 208, 208, 64) 18432       leaky_2[0][0]
# __________________________________________________________________________________________________
# bnorm_3 (BatchNormalization)    (None, 208, 208, 64) 256         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_3 (LeakyReLU)             (None, 208, 208, 64) 0           bnorm_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_156 (TFOpL (None, 208, 208, 64) 0           leaky_3[0][0]
#                                                                  leaky_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 209, 209, 64) 0           tf.__operators__.add_156[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 104, 104, 128 73728       zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# bnorm_5 (BatchNormalization)    (None, 104, 104, 128 512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_5 (LeakyReLU)             (None, 104, 104, 128 0           bnorm_5[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 104, 104, 64) 8192        leaky_5[0][0]
# __________________________________________________________________________________________________
# bnorm_6 (BatchNormalization)    (None, 104, 104, 64) 256         conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_6 (LeakyReLU)             (None, 104, 104, 64) 0           bnorm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 104, 104, 128 73728       leaky_6[0][0]
# __________________________________________________________________________________________________
# bnorm_7 (BatchNormalization)    (None, 104, 104, 128 512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_7 (LeakyReLU)             (None, 104, 104, 128 0           bnorm_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_157 (TFOpL (None, 104, 104, 128 0           leaky_7[0][0]
#                                                                  leaky_5[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 104, 104, 64) 8192        tf.__operators__.add_157[0][0]
# __________________________________________________________________________________________________
# bnorm_9 (BatchNormalization)    (None, 104, 104, 64) 256         conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_9 (LeakyReLU)             (None, 104, 104, 64) 0           bnorm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 104, 104, 128 73728       leaky_9[0][0]
# __________________________________________________________________________________________________
# bnorm_10 (BatchNormalization)   (None, 104, 104, 128 512         conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_10 (LeakyReLU)            (None, 104, 104, 128 0           bnorm_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_158 (TFOpL (None, 104, 104, 128 0           leaky_10[0][0]
#                                                                  tf.__operators__.add_157[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 105, 105, 128 0           tf.__operators__.add_158[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# bnorm_12 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_12 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 52, 52, 128)  32768       leaky_12[0][0]
# __________________________________________________________________________________________________
# bnorm_13 (BatchNormalization)   (None, 52, 52, 128)  512         conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_13 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_13[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 52, 52, 256)  294912      leaky_13[0][0]
# __________________________________________________________________________________________________
# bnorm_14 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_14 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_159 (TFOpL (None, 52, 52, 256)  0           leaky_14[0][0]
#                                                                  leaky_12[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_159[0][0]
# __________________________________________________________________________________________________
# bnorm_16 (BatchNormalization)   (None, 52, 52, 128)  512         conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_16 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 52, 52, 256)  294912      leaky_16[0][0]
# __________________________________________________________________________________________________
# bnorm_17 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_17 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_160 (TFOpL (None, 52, 52, 256)  0           leaky_17[0][0]
#                                                                  tf.__operators__.add_159[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_160[0][0]
# __________________________________________________________________________________________________
# bnorm_19 (BatchNormalization)   (None, 52, 52, 128)  512         conv_19[0][0]
# __________________________________________________________________________________________________
# leaky_19 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_19[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 52, 52, 256)  294912      leaky_19[0][0]
# __________________________________________________________________________________________________
# bnorm_20 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_20[0][0]
# __________________________________________________________________________________________________
# leaky_20 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_161 (TFOpL (None, 52, 52, 256)  0           leaky_20[0][0]
#                                                                  tf.__operators__.add_160[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_161[0][0]
# __________________________________________________________________________________________________
# bnorm_22 (BatchNormalization)   (None, 52, 52, 128)  512         conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_22 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_22[0][0]
# __________________________________________________________________________________________________
# conv_23 (Conv2D)                (None, 52, 52, 256)  294912      leaky_22[0][0]
# __________________________________________________________________________________________________
# bnorm_23 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_23[0][0]
# __________________________________________________________________________________________________
# leaky_23 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_23[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_162 (TFOpL (None, 52, 52, 256)  0           leaky_23[0][0]
#                                                                  tf.__operators__.add_161[0][0]
# __________________________________________________________________________________________________
# conv_25 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_162[0][0]
# __________________________________________________________________________________________________
# bnorm_25 (BatchNormalization)   (None, 52, 52, 128)  512         conv_25[0][0]
# __________________________________________________________________________________________________
# leaky_25 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_25[0][0]
# __________________________________________________________________________________________________
# conv_26 (Conv2D)                (None, 52, 52, 256)  294912      leaky_25[0][0]
# __________________________________________________________________________________________________
# bnorm_26 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_26[0][0]
# __________________________________________________________________________________________________
# leaky_26 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_26[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_163 (TFOpL (None, 52, 52, 256)  0           leaky_26[0][0]
#                                                                  tf.__operators__.add_162[0][0]
# __________________________________________________________________________________________________
# conv_28 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_163[0][0]
# __________________________________________________________________________________________________
# bnorm_28 (BatchNormalization)   (None, 52, 52, 128)  512         conv_28[0][0]
# __________________________________________________________________________________________________
# leaky_28 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_28[0][0]
# __________________________________________________________________________________________________
# conv_29 (Conv2D)                (None, 52, 52, 256)  294912      leaky_28[0][0]
# __________________________________________________________________________________________________
# bnorm_29 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_29[0][0]
# __________________________________________________________________________________________________
# leaky_29 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_164 (TFOpL (None, 52, 52, 256)  0           leaky_29[0][0]
#                                                                  tf.__operators__.add_163[0][0]
# __________________________________________________________________________________________________
# conv_31 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_164[0][0]
# __________________________________________________________________________________________________
# bnorm_31 (BatchNormalization)   (None, 52, 52, 128)  512         conv_31[0][0]
# __________________________________________________________________________________________________
# leaky_31 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_31[0][0]
# __________________________________________________________________________________________________
# conv_32 (Conv2D)                (None, 52, 52, 256)  294912      leaky_31[0][0]
# __________________________________________________________________________________________________
# bnorm_32 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_32[0][0]
# __________________________________________________________________________________________________
# leaky_32 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_32[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_165 (TFOpL (None, 52, 52, 256)  0           leaky_32[0][0]
#                                                                  tf.__operators__.add_164[0][0]
# __________________________________________________________________________________________________
# conv_34 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_165[0][0]
# __________________________________________________________________________________________________
# bnorm_34 (BatchNormalization)   (None, 52, 52, 128)  512         conv_34[0][0]
# __________________________________________________________________________________________________
# leaky_34 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_34[0][0]
# __________________________________________________________________________________________________
# conv_35 (Conv2D)                (None, 52, 52, 256)  294912      leaky_34[0][0]
# __________________________________________________________________________________________________
# bnorm_35 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_35[0][0]
# __________________________________________________________________________________________________
# leaky_35 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_35[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_166 (TFOpL (None, 52, 52, 256)  0           leaky_35[0][0]
#                                                                  tf.__operators__.add_165[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 53, 53, 256)  0           tf.__operators__.add_166[0][0]
# __________________________________________________________________________________________________
# conv_37 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_33[0][0]
# __________________________________________________________________________________________________
# bnorm_37 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_37[0][0]
# __________________________________________________________________________________________________
# leaky_37 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_37[0][0]
# __________________________________________________________________________________________________
# conv_38 (Conv2D)                (None, 26, 26, 256)  131072      leaky_37[0][0]
# __________________________________________________________________________________________________
# bnorm_38 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_38[0][0]
# __________________________________________________________________________________________________
# leaky_38 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_38[0][0]
# __________________________________________________________________________________________________
# conv_39 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_38[0][0]
# __________________________________________________________________________________________________
# bnorm_39 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_39[0][0]
# __________________________________________________________________________________________________
# leaky_39 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_39[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_167 (TFOpL (None, 26, 26, 512)  0           leaky_39[0][0]
#                                                                  leaky_37[0][0]
# __________________________________________________________________________________________________
# conv_41 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_167[0][0]
# __________________________________________________________________________________________________
# bnorm_41 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_41[0][0]
# __________________________________________________________________________________________________
# leaky_41 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_41[0][0]
# __________________________________________________________________________________________________
# conv_42 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_41[0][0]
# __________________________________________________________________________________________________
# bnorm_42 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_42[0][0]
# __________________________________________________________________________________________________
# leaky_42 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_42[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_168 (TFOpL (None, 26, 26, 512)  0           leaky_42[0][0]
#                                                                  tf.__operators__.add_167[0][0]
# __________________________________________________________________________________________________
# conv_44 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_168[0][0]
# __________________________________________________________________________________________________
# bnorm_44 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_44[0][0]
# __________________________________________________________________________________________________
# leaky_44 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_44[0][0]
# __________________________________________________________________________________________________
# conv_45 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_44[0][0]
# __________________________________________________________________________________________________
# bnorm_45 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_45[0][0]
# __________________________________________________________________________________________________
# leaky_45 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_45[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_169 (TFOpL (None, 26, 26, 512)  0           leaky_45[0][0]
#                                                                  tf.__operators__.add_168[0][0]
# __________________________________________________________________________________________________
# conv_47 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_169[0][0]
# __________________________________________________________________________________________________
# bnorm_47 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_47[0][0]
# __________________________________________________________________________________________________
# leaky_47 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_47[0][0]
# __________________________________________________________________________________________________
# conv_48 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_47[0][0]
# __________________________________________________________________________________________________
# bnorm_48 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_48[0][0]
# __________________________________________________________________________________________________
# leaky_48 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_48[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_170 (TFOpL (None, 26, 26, 512)  0           leaky_48[0][0]
#                                                                  tf.__operators__.add_169[0][0]
# __________________________________________________________________________________________________
# conv_50 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_170[0][0]
# __________________________________________________________________________________________________
# bnorm_50 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_50[0][0]
# __________________________________________________________________________________________________
# leaky_50 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_50[0][0]
# __________________________________________________________________________________________________
# conv_51 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_50[0][0]
# __________________________________________________________________________________________________
# bnorm_51 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_51[0][0]
# __________________________________________________________________________________________________
# leaky_51 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_51[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_171 (TFOpL (None, 26, 26, 512)  0           leaky_51[0][0]
#                                                                  tf.__operators__.add_170[0][0]
# __________________________________________________________________________________________________
# conv_53 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_171[0][0]
# __________________________________________________________________________________________________
# bnorm_53 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_53[0][0]
# __________________________________________________________________________________________________
# leaky_53 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_53[0][0]
# __________________________________________________________________________________________________
# conv_54 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_53[0][0]
# __________________________________________________________________________________________________
# bnorm_54 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_54[0][0]
# __________________________________________________________________________________________________
# leaky_54 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_54[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_172 (TFOpL (None, 26, 26, 512)  0           leaky_54[0][0]
#                                                                  tf.__operators__.add_171[0][0]
# __________________________________________________________________________________________________
# conv_56 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_172[0][0]
# __________________________________________________________________________________________________
# bnorm_56 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_56[0][0]
# __________________________________________________________________________________________________
# leaky_56 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_56[0][0]
# __________________________________________________________________________________________________
# conv_57 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_56[0][0]
# __________________________________________________________________________________________________
# bnorm_57 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_57[0][0]
# __________________________________________________________________________________________________
# leaky_57 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_57[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_173 (TFOpL (None, 26, 26, 512)  0           leaky_57[0][0]
#                                                                  tf.__operators__.add_172[0][0]
# __________________________________________________________________________________________________
# conv_59 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_173[0][0]
# __________________________________________________________________________________________________
# bnorm_59 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_59[0][0]
# __________________________________________________________________________________________________
# leaky_59 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_59[0][0]
# __________________________________________________________________________________________________
# conv_60 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_59[0][0]
# __________________________________________________________________________________________________
# bnorm_60 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_60[0][0]
# __________________________________________________________________________________________________
# leaky_60 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_60[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_174 (TFOpL (None, 26, 26, 512)  0           leaky_60[0][0]
#                                                                  tf.__operators__.add_173[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_34 (ZeroPadding2 (None, 27, 27, 512)  0           tf.__operators__.add_174[0][0]
# __________________________________________________________________________________________________
# conv_62 (Conv2D)                (None, 13, 13, 1024) 4718592     zero_padding2d_34[0][0]
# __________________________________________________________________________________________________
# bnorm_62 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_62[0][0]
# __________________________________________________________________________________________________
# leaky_62 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_62[0][0]
# __________________________________________________________________________________________________
# conv_63 (Conv2D)                (None, 13, 13, 512)  524288      leaky_62[0][0]
# __________________________________________________________________________________________________
# bnorm_63 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_63[0][0]
# __________________________________________________________________________________________________
# leaky_63 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_63[0][0]
# __________________________________________________________________________________________________
# conv_64 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_63[0][0]
# __________________________________________________________________________________________________
# bnorm_64 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_64[0][0]
# __________________________________________________________________________________________________
# leaky_64 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_64[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_175 (TFOpL (None, 13, 13, 1024) 0           leaky_64[0][0]
#                                                                  leaky_62[0][0]
# __________________________________________________________________________________________________
# conv_66 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_175[0][0]
# __________________________________________________________________________________________________
# bnorm_66 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_66[0][0]
# __________________________________________________________________________________________________
# leaky_66 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_66[0][0]
# __________________________________________________________________________________________________
# conv_67 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_66[0][0]
# __________________________________________________________________________________________________
# bnorm_67 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_67[0][0]
# __________________________________________________________________________________________________
# leaky_67 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_67[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_176 (TFOpL (None, 13, 13, 1024) 0           leaky_67[0][0]
#                                                                  tf.__operators__.add_175[0][0]
# __________________________________________________________________________________________________
# conv_69 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_176[0][0]
# __________________________________________________________________________________________________
# bnorm_69 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_69[0][0]
# __________________________________________________________________________________________________
# leaky_69 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_69[0][0]
# __________________________________________________________________________________________________
# conv_70 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_69[0][0]
# __________________________________________________________________________________________________
# bnorm_70 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_70[0][0]
# __________________________________________________________________________________________________
# leaky_70 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_70[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_177 (TFOpL (None, 13, 13, 1024) 0           leaky_70[0][0]
#                                                                  tf.__operators__.add_176[0][0]
# __________________________________________________________________________________________________
# conv_72 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_177[0][0]
# __________________________________________________________________________________________________
# bnorm_72 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_72[0][0]
# __________________________________________________________________________________________________
# leaky_72 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_72[0][0]
# __________________________________________________________________________________________________
# conv_73 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_72[0][0]
# __________________________________________________________________________________________________
# bnorm_73 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_73[0][0]
# __________________________________________________________________________________________________
# leaky_73 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_73[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_178 (TFOpL (None, 13, 13, 1024) 0           leaky_73[0][0]
#                                                                  tf.__operators__.add_177[0][0]
# __________________________________________________________________________________________________
# conv_75 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_178[0][0]
# __________________________________________________________________________________________________
# bnorm_75 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_75[0][0]
# __________________________________________________________________________________________________
# leaky_75 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_75[0][0]
# __________________________________________________________________________________________________
# conv_76 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_75[0][0]
# __________________________________________________________________________________________________
# bnorm_76 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_76[0][0]
# __________________________________________________________________________________________________
# leaky_76 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_76[0][0]
# __________________________________________________________________________________________________
# conv_77 (Conv2D)                (None, 13, 13, 512)  524288      leaky_76[0][0]
# __________________________________________________________________________________________________
# bnorm_77 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_77[0][0]
# __________________________________________________________________________________________________
# leaky_77 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_77[0][0]
# __________________________________________________________________________________________________
# conv_78 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_77[0][0]
# __________________________________________________________________________________________________
# bnorm_78 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_78[0][0]
# __________________________________________________________________________________________________
# leaky_78 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_78[0][0]
# __________________________________________________________________________________________________
# conv_79 (Conv2D)                (None, 13, 13, 512)  524288      leaky_78[0][0]
# __________________________________________________________________________________________________
# bnorm_79 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_79[0][0]
# __________________________________________________________________________________________________
# leaky_79 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_79[0][0]
# __________________________________________________________________________________________________
# conv_84 (Conv2D)                (None, 13, 13, 256)  131072      leaky_79[0][0]
# __________________________________________________________________________________________________
# bnorm_84 (BatchNormalization)   (None, 13, 13, 256)  1024        conv_84[0][0]
# __________________________________________________________________________________________________
# leaky_84 (LeakyReLU)            (None, 13, 13, 256)  0           bnorm_84[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 26, 26, 256)  0           leaky_84[0][0]
# __________________________________________________________________________________________________
# tf.concat_43 (TFOpLambda)       (None, 26, 26, 768)  0           up_sampling2d_12[0][0]
#                                                                  tf.__operators__.add_174[0][0]
# __________________________________________________________________________________________________
# conv_87 (Conv2D)                (None, 26, 26, 256)  196608      tf.concat_43[0][0]
# __________________________________________________________________________________________________
# bnorm_87 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_87[0][0]
# __________________________________________________________________________________________________
# leaky_87 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_87[0][0]
# __________________________________________________________________________________________________
# conv_88 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_87[0][0]
# __________________________________________________________________________________________________
# bnorm_88 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_88[0][0]
# __________________________________________________________________________________________________
# leaky_88 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_88[0][0]
# __________________________________________________________________________________________________
# conv_89 (Conv2D)                (None, 26, 26, 256)  131072      leaky_88[0][0]
# __________________________________________________________________________________________________
# bnorm_89 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_89[0][0]
# __________________________________________________________________________________________________
# leaky_89 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_89[0][0]
# __________________________________________________________________________________________________
# conv_90 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_89[0][0]
# __________________________________________________________________________________________________
# bnorm_90 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_90[0][0]
# __________________________________________________________________________________________________
# leaky_90 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_90[0][0]
# __________________________________________________________________________________________________
# conv_91 (Conv2D)                (None, 26, 26, 256)  131072      leaky_90[0][0]
# __________________________________________________________________________________________________
# bnorm_91 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_91[0][0]
# __________________________________________________________________________________________________
# leaky_91 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_91[0][0]
# __________________________________________________________________________________________________
# conv_96 (Conv2D)                (None, 26, 26, 128)  32768       leaky_91[0][0]
# __________________________________________________________________________________________________
# bnorm_96 (BatchNormalization)   (None, 26, 26, 128)  512         conv_96[0][0]
# __________________________________________________________________________________________________
# leaky_96 (LeakyReLU)            (None, 26, 26, 128)  0           bnorm_96[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 52, 52, 128)  0           leaky_96[0][0]
# __________________________________________________________________________________________________
# tf.concat_46 (TFOpLambda)       (None, 52, 52, 384)  0           up_sampling2d_13[0][0]
#                                                                  tf.__operators__.add_166[0][0]
# __________________________________________________________________________________________________
# conv_99 (Conv2D)                (None, 52, 52, 128)  49152       tf.concat_46[0][0]
# __________________________________________________________________________________________________
# bnorm_99 (BatchNormalization)   (None, 52, 52, 128)  512         conv_99[0][0]
# __________________________________________________________________________________________________
# ...
# tf.math.sigmoid_62 (TFOpLambda) (None, 8112, 80)     0           tf.__operators__.getitem_83[0][0]
# __________________________________________________________________________________________________
# tf.concat_45 (TFOpLambda)       (None, 2535, 85)     0           tf.concat_42[0][0]
#                                                                  tf.concat_44[0][0]
# __________________________________________________________________________________________________
# tf.concat_47 (TFOpLambda)       (None, 8112, 85)     0           tf.math.multiply_41[0][0]
#                                                                  tf.math.multiply_40[0][0]
#                                                                  tf.math.sigmoid_61[0][0]
#                                                                  tf.math.sigmoid_62[0][0]
# __________________________________________________________________________________________________
# tf.concat_48 (TFOpLambda)       (None, 10647, 85)    0           tf.concat_45[0][0]
#                                                                  tf.concat_47[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# layer:  1 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51c4f3aac0>
# layer:  1 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a2d920a0>
# layer:  2 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51599cf4c0>
# layer:  2 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51599c62b0>
# layer:  3 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51577f6a90>
# layer:  3 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51577f6ac0>
# layer:  4 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a0e683d0>
# layer:  4 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a0e6ea30>
# layer:  6 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51599cf940>
# layer:  6 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159a318e0>
# layer:  7 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157825a60>
# layer:  7 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159a27190>
# layer:  8 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51599c6070>
# layer:  8 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159a223d0>
# layer:  10 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a0ecadc0>
# layer:  10 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159a273d0>
# layer:  11 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159aefdc0>
# layer:  11 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159ae9070>
# layer:  13 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159ae06d0>
# layer:  13 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159b38b80>
# layer:  14 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159b28c40>
# layer:  14 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159a80fd0>
# layer:  15 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159b0f670>
# layer:  15 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159ae9700>
# layer:  17 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159b5bca0>
# layer:  17 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a0f9e400>
# layer:  18 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a0fd0af0>
# layer:  18 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159b61370>
# layer:  20 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159b9c220>
# layer:  20 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159b4e880>
# layer:  21 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a1068df0>
# layer:  21 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f515799f160>
# layer:  23 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a104b160>
# layer:  23 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159bd16a0>
# layer:  24 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a109ac10>
# layer:  24 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159bd1670>
# layer:  26 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159be0c10>
# layer:  26 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a10ab6d0>
# layer:  27 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159a884c0>
# layer:  27 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159b780d0>
# layer:  29 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a0ed7b50>
# layer:  29 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159b219a0>
# layer:  30 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159c0fe80>
# layer:  30 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159c210a0>
# layer:  32 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159c026a0>
# layer:  32 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a10d8910>
# layer:  33 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159c52c40>
# layer:  33 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a107be20>
# layer:  35 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a110f5b0>
# layer:  35 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159cbb820>
# layer:  36 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159c82670>
# layer:  36 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159c8aa30>
# layer:  38 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a113c280>
# layer:  38 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159c8a580>
# layer:  39 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a11a47f0>
# layer:  39 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5157b16ee0>
# layer:  40 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a11f2c70>
# layer:  40 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159c99310>
# layer:  42 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159d21fd0>
# layer:  42 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159d3da60>
# layer:  43 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157b0ed00>
# layer:  43 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5157b0e730>
# layer:  45 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a1131c10>
# layer:  45 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a1194550>
# layer:  46 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159b6a4c0>
# layer:  46 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159d3d4c0>
# layer:  48 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a12256a0>
# layer:  48 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a1006250>
# layer:  49 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159d43b20>
# layer:  49 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159c0fb50>
# layer:  51 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159db3220>
# layer:  51 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159dbbdc0>
# layer:  52 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159d9aac0>
# layer:  52 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159dbb8e0>
# layer:  54 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a22eeb50>
# layer:  54 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159df4af0>
# layer:  55 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159dde2b0>
# layer:  55 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159df40a0>
# layer:  57 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159e3d4c0>
# layer:  57 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159daca90>
# layer:  58 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157c8cca0>
# layer:  58 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a22b8970>
# layer:  60 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a236a7c0>
# layer:  60 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159e20a60>
# layer:  61 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a22d8460>
# layer:  61 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159e20d90>
# layer:  63 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a11f6df0>
# layer:  63 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5157cfd760>
# layer:  64 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159e2eee0>
# layer:  64 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159e69040>
# layer:  65 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157d201f0>
# layer:  65 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159e18b20>
# layer:  67 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159eb1310>
# layer:  67 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159ea95b0>
# layer:  68 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159e9a340>
# layer:  68 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a237d0a0>
# layer:  70 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a23f4850>
# layer:  70 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159e979d0>
# layer:  71 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157db86d0>
# layer:  71 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159ee3a90>
# layer:  73 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159ecd9a0>
# layer:  73 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159edd700>
# layer:  74 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157e37e80>
# layer:  74 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159edddf0>
# layer:  76 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a2439f40>
# layer:  76 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a2455f70>
# layer:  77 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a2485580>
# layer:  77 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a2413bb0>
# layer:  78 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a2403790>
# layer:  78 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5157dc8a30>
# layer:  79 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159ea9880>
# layer:  79 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a23485b0>
# layer:  80 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a224afd0>
# layer:  80 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159ea97f0>
# layer:  81 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157e00610>
# layer:  81 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a237d400>
# layer:  82 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159e2e940>
# layer:  85 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159df47f0>
# layer:  85 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159fc9700>
# layer:  88 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159fe9cd0>
# layer:  88 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159ff66a0>
# layer:  89 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a00456d0>
# layer:  89 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a256f550>
# layer:  90 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a003e1c0>
# layer:  90 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5159fc94c0>
# layer:  91 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a259af40>
# layer:  91 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a00387f0>
# layer:  92 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157e98e20>
# layer:  92 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a00385b0>
# layer:  93 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a12257f0>
# layer:  93 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5157eb1bb0>
# layer:  94 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5159fdf100>
# layer:  97 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a262b9d0>
# layer:  97 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a0080580>
# layer:  100 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a0085c70>
# layer:  100 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a0080e20>
# layer:  101 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a25dbc40>
# layer:  101 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a2632820>
# layer:  102 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a00be400>
# layer:  102 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a25ba040>
# layer:  103 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a2607a90>
# layer:  103 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a01309d0>
# layer:  104 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5157fd4430>
# layer:  104 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a011c940>
# layer:  105 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a0163f40>
# layer:  105 <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f51a00f7310>
# layer:  106 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f51a261d100>
# INFO:tensorflow:Assets written to: /home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3_model.pb/assets
#
# The model 'yolov3' has been saved successfully.

# %%
from tensorflow import keras
model_location='/home/craig/Documents/YOLO-3-OpenCV/yolo3_tf/yolov3_model'
model=keras.models.load_model(model_location)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# tf.math.truediv_6 (TFOpLambda)  (None, 416, 416, 3)  0           input_7[0][0]
# __________________________________________________________________________________________________
# conv_0 (Conv2D)                 (None, 416, 416, 32) 864         tf.math.truediv_6[0][0]
# __________________________________________________________________________________________________
# bnorm_0 (BatchNormalization)    (None, 416, 416, 32) 128         conv_0[0][0]
# __________________________________________________________________________________________________
# leaky_0 (LeakyReLU)             (None, 416, 416, 32) 0           bnorm_0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 417, 417, 32) 0           leaky_0[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 208, 208, 64) 18432       zero_padding2d_30[0][0]
# __________________________________________________________________________________________________
# bnorm_1 (BatchNormalization)    (None, 208, 208, 64) 256         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_1 (LeakyReLU)             (None, 208, 208, 64) 0           bnorm_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 208, 208, 32) 2048        leaky_1[0][0]
# __________________________________________________________________________________________________
# bnorm_2 (BatchNormalization)    (None, 208, 208, 32) 128         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_2 (LeakyReLU)             (None, 208, 208, 32) 0           bnorm_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 208, 208, 64) 18432       leaky_2[0][0]
# __________________________________________________________________________________________________
# bnorm_3 (BatchNormalization)    (None, 208, 208, 64) 256         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_3 (LeakyReLU)             (None, 208, 208, 64) 0           bnorm_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_156 (TFOpL (None, 208, 208, 64) 0           leaky_3[0][0]
#                                                                  leaky_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 209, 209, 64) 0           tf.__operators__.add_156[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 104, 104, 128 73728       zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# bnorm_5 (BatchNormalization)    (None, 104, 104, 128 512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_5 (LeakyReLU)             (None, 104, 104, 128 0           bnorm_5[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 104, 104, 64) 8192        leaky_5[0][0]
# __________________________________________________________________________________________________
# bnorm_6 (BatchNormalization)    (None, 104, 104, 64) 256         conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_6 (LeakyReLU)             (None, 104, 104, 64) 0           bnorm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 104, 104, 128 73728       leaky_6[0][0]
# __________________________________________________________________________________________________
# bnorm_7 (BatchNormalization)    (None, 104, 104, 128 512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_7 (LeakyReLU)             (None, 104, 104, 128 0           bnorm_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_157 (TFOpL (None, 104, 104, 128 0           leaky_7[0][0]
#                                                                  leaky_5[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 104, 104, 64) 8192        tf.__operators__.add_157[0][0]
# __________________________________________________________________________________________________
# bnorm_9 (BatchNormalization)    (None, 104, 104, 64) 256         conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_9 (LeakyReLU)             (None, 104, 104, 64) 0           bnorm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 104, 104, 128 73728       leaky_9[0][0]
# __________________________________________________________________________________________________
# bnorm_10 (BatchNormalization)   (None, 104, 104, 128 512         conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_10 (LeakyReLU)            (None, 104, 104, 128 0           bnorm_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_158 (TFOpL (None, 104, 104, 128 0           leaky_10[0][0]
#                                                                  tf.__operators__.add_157[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 105, 105, 128 0           tf.__operators__.add_158[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 52, 52, 256)  294912      zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# bnorm_12 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_12 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 52, 52, 128)  32768       leaky_12[0][0]
# __________________________________________________________________________________________________
# bnorm_13 (BatchNormalization)   (None, 52, 52, 128)  512         conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_13 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_13[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 52, 52, 256)  294912      leaky_13[0][0]
# __________________________________________________________________________________________________
# bnorm_14 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_14 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_159 (TFOpL (None, 52, 52, 256)  0           leaky_14[0][0]
#                                                                  leaky_12[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_159[0][0]
# __________________________________________________________________________________________________
# bnorm_16 (BatchNormalization)   (None, 52, 52, 128)  512         conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_16 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 52, 52, 256)  294912      leaky_16[0][0]
# __________________________________________________________________________________________________
# bnorm_17 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_17 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_17[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_160 (TFOpL (None, 52, 52, 256)  0           leaky_17[0][0]
#                                                                  tf.__operators__.add_159[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_160[0][0]
# __________________________________________________________________________________________________
# bnorm_19 (BatchNormalization)   (None, 52, 52, 128)  512         conv_19[0][0]
# __________________________________________________________________________________________________
# leaky_19 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_19[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 52, 52, 256)  294912      leaky_19[0][0]
# __________________________________________________________________________________________________
# bnorm_20 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_20[0][0]
# __________________________________________________________________________________________________
# leaky_20 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_161 (TFOpL (None, 52, 52, 256)  0           leaky_20[0][0]
#                                                                  tf.__operators__.add_160[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_161[0][0]
# __________________________________________________________________________________________________
# bnorm_22 (BatchNormalization)   (None, 52, 52, 128)  512         conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_22 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_22[0][0]
# __________________________________________________________________________________________________
# conv_23 (Conv2D)                (None, 52, 52, 256)  294912      leaky_22[0][0]
# __________________________________________________________________________________________________
# bnorm_23 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_23[0][0]
# __________________________________________________________________________________________________
# leaky_23 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_23[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_162 (TFOpL (None, 52, 52, 256)  0           leaky_23[0][0]
#                                                                  tf.__operators__.add_161[0][0]
# __________________________________________________________________________________________________
# conv_25 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_162[0][0]
# __________________________________________________________________________________________________
# bnorm_25 (BatchNormalization)   (None, 52, 52, 128)  512         conv_25[0][0]
# __________________________________________________________________________________________________
# leaky_25 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_25[0][0]
# __________________________________________________________________________________________________
# conv_26 (Conv2D)                (None, 52, 52, 256)  294912      leaky_25[0][0]
# __________________________________________________________________________________________________
# bnorm_26 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_26[0][0]
# __________________________________________________________________________________________________
# leaky_26 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_26[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_163 (TFOpL (None, 52, 52, 256)  0           leaky_26[0][0]
#                                                                  tf.__operators__.add_162[0][0]
# __________________________________________________________________________________________________
# conv_28 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_163[0][0]
# __________________________________________________________________________________________________
# bnorm_28 (BatchNormalization)   (None, 52, 52, 128)  512         conv_28[0][0]
# __________________________________________________________________________________________________
# leaky_28 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_28[0][0]
# __________________________________________________________________________________________________
# conv_29 (Conv2D)                (None, 52, 52, 256)  294912      leaky_28[0][0]
# __________________________________________________________________________________________________
# bnorm_29 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_29[0][0]
# __________________________________________________________________________________________________
# leaky_29 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_164 (TFOpL (None, 52, 52, 256)  0           leaky_29[0][0]
#                                                                  tf.__operators__.add_163[0][0]
# __________________________________________________________________________________________________
# conv_31 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_164[0][0]
# __________________________________________________________________________________________________
# bnorm_31 (BatchNormalization)   (None, 52, 52, 128)  512         conv_31[0][0]
# __________________________________________________________________________________________________
# leaky_31 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_31[0][0]
# __________________________________________________________________________________________________
# conv_32 (Conv2D)                (None, 52, 52, 256)  294912      leaky_31[0][0]
# __________________________________________________________________________________________________
# bnorm_32 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_32[0][0]
# __________________________________________________________________________________________________
# leaky_32 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_32[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_165 (TFOpL (None, 52, 52, 256)  0           leaky_32[0][0]
#                                                                  tf.__operators__.add_164[0][0]
# __________________________________________________________________________________________________
# conv_34 (Conv2D)                (None, 52, 52, 128)  32768       tf.__operators__.add_165[0][0]
# __________________________________________________________________________________________________
# bnorm_34 (BatchNormalization)   (None, 52, 52, 128)  512         conv_34[0][0]
# __________________________________________________________________________________________________
# leaky_34 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_34[0][0]
# __________________________________________________________________________________________________
# conv_35 (Conv2D)                (None, 52, 52, 256)  294912      leaky_34[0][0]
# __________________________________________________________________________________________________
# bnorm_35 (BatchNormalization)   (None, 52, 52, 256)  1024        conv_35[0][0]
# __________________________________________________________________________________________________
# leaky_35 (LeakyReLU)            (None, 52, 52, 256)  0           bnorm_35[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_166 (TFOpL (None, 52, 52, 256)  0           leaky_35[0][0]
#                                                                  tf.__operators__.add_165[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 53, 53, 256)  0           tf.__operators__.add_166[0][0]
# __________________________________________________________________________________________________
# conv_37 (Conv2D)                (None, 26, 26, 512)  1179648     zero_padding2d_33[0][0]
# __________________________________________________________________________________________________
# bnorm_37 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_37[0][0]
# __________________________________________________________________________________________________
# leaky_37 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_37[0][0]
# __________________________________________________________________________________________________
# conv_38 (Conv2D)                (None, 26, 26, 256)  131072      leaky_37[0][0]
# __________________________________________________________________________________________________
# bnorm_38 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_38[0][0]
# __________________________________________________________________________________________________
# leaky_38 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_38[0][0]
# __________________________________________________________________________________________________
# conv_39 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_38[0][0]
# __________________________________________________________________________________________________
# bnorm_39 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_39[0][0]
# __________________________________________________________________________________________________
# leaky_39 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_39[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_167 (TFOpL (None, 26, 26, 512)  0           leaky_39[0][0]
#                                                                  leaky_37[0][0]
# __________________________________________________________________________________________________
# conv_41 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_167[0][0]
# __________________________________________________________________________________________________
# bnorm_41 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_41[0][0]
# __________________________________________________________________________________________________
# leaky_41 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_41[0][0]
# __________________________________________________________________________________________________
# conv_42 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_41[0][0]
# __________________________________________________________________________________________________
# bnorm_42 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_42[0][0]
# __________________________________________________________________________________________________
# leaky_42 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_42[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_168 (TFOpL (None, 26, 26, 512)  0           leaky_42[0][0]
#                                                                  tf.__operators__.add_167[0][0]
# __________________________________________________________________________________________________
# conv_44 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_168[0][0]
# __________________________________________________________________________________________________
# bnorm_44 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_44[0][0]
# __________________________________________________________________________________________________
# leaky_44 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_44[0][0]
# __________________________________________________________________________________________________
# conv_45 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_44[0][0]
# __________________________________________________________________________________________________
# bnorm_45 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_45[0][0]
# __________________________________________________________________________________________________
# leaky_45 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_45[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_169 (TFOpL (None, 26, 26, 512)  0           leaky_45[0][0]
#                                                                  tf.__operators__.add_168[0][0]
# __________________________________________________________________________________________________
# conv_47 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_169[0][0]
# __________________________________________________________________________________________________
# bnorm_47 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_47[0][0]
# __________________________________________________________________________________________________
# leaky_47 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_47[0][0]
# __________________________________________________________________________________________________
# conv_48 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_47[0][0]
# __________________________________________________________________________________________________
# bnorm_48 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_48[0][0]
# __________________________________________________________________________________________________
# leaky_48 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_48[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_170 (TFOpL (None, 26, 26, 512)  0           leaky_48[0][0]
#                                                                  tf.__operators__.add_169[0][0]
# __________________________________________________________________________________________________
# conv_50 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_170[0][0]
# __________________________________________________________________________________________________
# bnorm_50 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_50[0][0]
# __________________________________________________________________________________________________
# leaky_50 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_50[0][0]
# __________________________________________________________________________________________________
# conv_51 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_50[0][0]
# __________________________________________________________________________________________________
# bnorm_51 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_51[0][0]
# __________________________________________________________________________________________________
# leaky_51 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_51[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_171 (TFOpL (None, 26, 26, 512)  0           leaky_51[0][0]
#                                                                  tf.__operators__.add_170[0][0]
# __________________________________________________________________________________________________
# conv_53 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_171[0][0]
# __________________________________________________________________________________________________
# bnorm_53 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_53[0][0]
# __________________________________________________________________________________________________
# leaky_53 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_53[0][0]
# __________________________________________________________________________________________________
# conv_54 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_53[0][0]
# __________________________________________________________________________________________________
# bnorm_54 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_54[0][0]
# __________________________________________________________________________________________________
# leaky_54 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_54[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_172 (TFOpL (None, 26, 26, 512)  0           leaky_54[0][0]
#                                                                  tf.__operators__.add_171[0][0]
# __________________________________________________________________________________________________
# conv_56 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_172[0][0]
# __________________________________________________________________________________________________
# bnorm_56 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_56[0][0]
# __________________________________________________________________________________________________
# leaky_56 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_56[0][0]
# __________________________________________________________________________________________________
# conv_57 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_56[0][0]
# __________________________________________________________________________________________________
# bnorm_57 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_57[0][0]
# __________________________________________________________________________________________________
# leaky_57 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_57[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_173 (TFOpL (None, 26, 26, 512)  0           leaky_57[0][0]
#                                                                  tf.__operators__.add_172[0][0]
# __________________________________________________________________________________________________
# conv_59 (Conv2D)                (None, 26, 26, 256)  131072      tf.__operators__.add_173[0][0]
# __________________________________________________________________________________________________
# bnorm_59 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_59[0][0]
# __________________________________________________________________________________________________
# leaky_59 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_59[0][0]
# __________________________________________________________________________________________________
# conv_60 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_59[0][0]
# __________________________________________________________________________________________________
# bnorm_60 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_60[0][0]
# __________________________________________________________________________________________________
# leaky_60 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_60[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_174 (TFOpL (None, 26, 26, 512)  0           leaky_60[0][0]
#                                                                  tf.__operators__.add_173[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_34 (ZeroPadding2 (None, 27, 27, 512)  0           tf.__operators__.add_174[0][0]
# __________________________________________________________________________________________________
# conv_62 (Conv2D)                (None, 13, 13, 1024) 4718592     zero_padding2d_34[0][0]
# __________________________________________________________________________________________________
# bnorm_62 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_62[0][0]
# __________________________________________________________________________________________________
# leaky_62 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_62[0][0]
# __________________________________________________________________________________________________
# conv_63 (Conv2D)                (None, 13, 13, 512)  524288      leaky_62[0][0]
# __________________________________________________________________________________________________
# bnorm_63 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_63[0][0]
# __________________________________________________________________________________________________
# leaky_63 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_63[0][0]
# __________________________________________________________________________________________________
# conv_64 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_63[0][0]
# __________________________________________________________________________________________________
# bnorm_64 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_64[0][0]
# __________________________________________________________________________________________________
# leaky_64 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_64[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_175 (TFOpL (None, 13, 13, 1024) 0           leaky_64[0][0]
#                                                                  leaky_62[0][0]
# __________________________________________________________________________________________________
# conv_66 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_175[0][0]
# __________________________________________________________________________________________________
# bnorm_66 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_66[0][0]
# __________________________________________________________________________________________________
# leaky_66 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_66[0][0]
# __________________________________________________________________________________________________
# conv_67 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_66[0][0]
# __________________________________________________________________________________________________
# bnorm_67 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_67[0][0]
# __________________________________________________________________________________________________
# leaky_67 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_67[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_176 (TFOpL (None, 13, 13, 1024) 0           leaky_67[0][0]
#                                                                  tf.__operators__.add_175[0][0]
# __________________________________________________________________________________________________
# conv_69 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_176[0][0]
# __________________________________________________________________________________________________
# bnorm_69 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_69[0][0]
# __________________________________________________________________________________________________
# leaky_69 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_69[0][0]
# __________________________________________________________________________________________________
# conv_70 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_69[0][0]
# __________________________________________________________________________________________________
# bnorm_70 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_70[0][0]
# __________________________________________________________________________________________________
# leaky_70 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_70[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_177 (TFOpL (None, 13, 13, 1024) 0           leaky_70[0][0]
#                                                                  tf.__operators__.add_176[0][0]
# __________________________________________________________________________________________________
# conv_72 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_177[0][0]
# __________________________________________________________________________________________________
# bnorm_72 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_72[0][0]
# __________________________________________________________________________________________________
# leaky_72 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_72[0][0]
# __________________________________________________________________________________________________
# conv_73 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_72[0][0]
# __________________________________________________________________________________________________
# bnorm_73 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_73[0][0]
# __________________________________________________________________________________________________
# leaky_73 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_73[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_178 (TFOpL (None, 13, 13, 1024) 0           leaky_73[0][0]
#                                                                  tf.__operators__.add_177[0][0]
# __________________________________________________________________________________________________
# conv_75 (Conv2D)                (None, 13, 13, 512)  524288      tf.__operators__.add_178[0][0]
# __________________________________________________________________________________________________
# bnorm_75 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_75[0][0]
# __________________________________________________________________________________________________
# leaky_75 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_75[0][0]
# __________________________________________________________________________________________________
# conv_76 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_75[0][0]
# __________________________________________________________________________________________________
# bnorm_76 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_76[0][0]
# __________________________________________________________________________________________________
# leaky_76 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_76[0][0]
# __________________________________________________________________________________________________
# conv_77 (Conv2D)                (None, 13, 13, 512)  524288      leaky_76[0][0]
# __________________________________________________________________________________________________
# bnorm_77 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_77[0][0]
# __________________________________________________________________________________________________
# leaky_77 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_77[0][0]
# __________________________________________________________________________________________________
# conv_78 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_77[0][0]
# __________________________________________________________________________________________________
# bnorm_78 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_78[0][0]
# __________________________________________________________________________________________________
# leaky_78 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_78[0][0]
# __________________________________________________________________________________________________
# conv_79 (Conv2D)                (None, 13, 13, 512)  524288      leaky_78[0][0]
# __________________________________________________________________________________________________
# bnorm_79 (BatchNormalization)   (None, 13, 13, 512)  2048        conv_79[0][0]
# __________________________________________________________________________________________________
# leaky_79 (LeakyReLU)            (None, 13, 13, 512)  0           bnorm_79[0][0]
# __________________________________________________________________________________________________
# conv_84 (Conv2D)                (None, 13, 13, 256)  131072      leaky_79[0][0]
# __________________________________________________________________________________________________
# bnorm_84 (BatchNormalization)   (None, 13, 13, 256)  1024        conv_84[0][0]
# __________________________________________________________________________________________________
# leaky_84 (LeakyReLU)            (None, 13, 13, 256)  0           bnorm_84[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 26, 26, 256)  0           leaky_84[0][0]
# __________________________________________________________________________________________________
# tf.concat_43 (TFOpLambda)       (None, 26, 26, 768)  0           up_sampling2d_12[0][0]
#                                                                  tf.__operators__.add_174[0][0]
# __________________________________________________________________________________________________
# conv_87 (Conv2D)                (None, 26, 26, 256)  196608      tf.concat_43[0][0]
# __________________________________________________________________________________________________
# bnorm_87 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_87[0][0]
# __________________________________________________________________________________________________
# leaky_87 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_87[0][0]
# __________________________________________________________________________________________________
# conv_88 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_87[0][0]
# __________________________________________________________________________________________________
# bnorm_88 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_88[0][0]
# __________________________________________________________________________________________________
# leaky_88 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_88[0][0]
# __________________________________________________________________________________________________
# conv_89 (Conv2D)                (None, 26, 26, 256)  131072      leaky_88[0][0]
# __________________________________________________________________________________________________
# bnorm_89 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_89[0][0]
# __________________________________________________________________________________________________
# leaky_89 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_89[0][0]
# __________________________________________________________________________________________________
# conv_90 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_89[0][0]
# __________________________________________________________________________________________________
# bnorm_90 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_90[0][0]
# __________________________________________________________________________________________________
# leaky_90 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_90[0][0]
# __________________________________________________________________________________________________
# conv_91 (Conv2D)                (None, 26, 26, 256)  131072      leaky_90[0][0]
# __________________________________________________________________________________________________
# bnorm_91 (BatchNormalization)   (None, 26, 26, 256)  1024        conv_91[0][0]
# __________________________________________________________________________________________________
# leaky_91 (LeakyReLU)            (None, 26, 26, 256)  0           bnorm_91[0][0]
# __________________________________________________________________________________________________
# conv_96 (Conv2D)                (None, 26, 26, 128)  32768       leaky_91[0][0]
# __________________________________________________________________________________________________
# bnorm_96 (BatchNormalization)   (None, 26, 26, 128)  512         conv_96[0][0]
# __________________________________________________________________________________________________
# leaky_96 (LeakyReLU)            (None, 26, 26, 128)  0           bnorm_96[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 52, 52, 128)  0           leaky_96[0][0]
# __________________________________________________________________________________________________
# tf.concat_46 (TFOpLambda)       (None, 52, 52, 384)  0           up_sampling2d_13[0][0]
#                                                                  tf.__operators__.add_166[0][0]
# __________________________________________________________________________________________________
# conv_99 (Conv2D)                (None, 52, 52, 128)  49152       tf.concat_46[0][0]
# __________________________________________________________________________________________________
# bnorm_99 (BatchNormalization)   (None, 52, 52, 128)  512         conv_99[0][0]
# __________________________________________________________________________________________________
# leaky_99 (LeakyReLU)            (None, 52, 52, 128)  0           bnorm_99[0][0]
# __________________________________________________________________________________________________
# conv_100 (Conv2D)               (None, 52, 52, 256)  294912      leaky_99[0][0]
# __________________________________________________________________________________________________
# bnorm_100 (BatchNormalization)  (None, 52, 52, 256)  1024        conv_100[0][0]
# __________________________________________________________________________________________________
# leaky_100 (LeakyReLU)           (None, 52, 52, 256)  0           bnorm_100[0][0]
# __________________________________________________________________________________________________
# conv_101 (Conv2D)               (None, 52, 52, 128)  32768       leaky_100[0][0]
# __________________________________________________________________________________________________
# bnorm_101 (BatchNormalization)  (None, 52, 52, 128)  512         conv_101[0][0]
# __________________________________________________________________________________________________
# leaky_101 (LeakyReLU)           (None, 52, 52, 128)  0           bnorm_101[0][0]
# __________________________________________________________________________________________________
# conv_102 (Conv2D)               (None, 52, 52, 256)  294912      leaky_101[0][0]
# __________________________________________________________________________________________________
# bnorm_102 (BatchNormalization)  (None, 52, 52, 256)  1024        conv_102[0][0]
# __________________________________________________________________________________________________
# leaky_102 (LeakyReLU)           (None, 52, 52, 256)  0           bnorm_102[0][0]
# __________________________________________________________________________________________________
# conv_103 (Conv2D)               (None, 52, 52, 128)  32768       leaky_102[0][0]
# __________________________________________________________________________________________________
# bnorm_103 (BatchNormalization)  (None, 52, 52, 128)  512         conv_103[0][0]
# __________________________________________________________________________________________________
# conv_80 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_79[0][0]
# __________________________________________________________________________________________________
# conv_92 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_91[0][0]
# __________________________________________________________________________________________________
# leaky_103 (LeakyReLU)           (None, 52, 52, 128)  0           bnorm_103[0][0]
# __________________________________________________________________________________________________
# bnorm_80 (BatchNormalization)   (None, 13, 13, 1024) 4096        conv_80[0][0]
# __________________________________________________________________________________________________
# bnorm_92 (BatchNormalization)   (None, 26, 26, 512)  2048        conv_92[0][0]
# __________________________________________________________________________________________________
# conv_104 (Conv2D)               (None, 52, 52, 256)  294912      leaky_103[0][0]
# __________________________________________________________________________________________________
# leaky_80 (LeakyReLU)            (None, 13, 13, 1024) 0           bnorm_80[0][0]
# __________________________________________________________________________________________________
# leaky_92 (LeakyReLU)            (None, 26, 26, 512)  0           bnorm_92[0][0]
# __________________________________________________________________________________________________
# bnorm_104 (BatchNormalization)  (None, 52, 52, 256)  1024        conv_104[0][0]
# __________________________________________________________________________________________________
# conv_81 (Conv2D)                (None, 13, 13, 255)  261375      leaky_80[0][0]
# __________________________________________________________________________________________________
# conv_93 (Conv2D)                (None, 26, 26, 255)  130815      leaky_92[0][0]
# __________________________________________________________________________________________________
# leaky_104 (LeakyReLU)           (None, 52, 52, 256)  0           bnorm_104[0][0]
# __________________________________________________________________________________________________
# tf.reshape_18 (TFOpLambda)      (None, 507, 85)      0           conv_81[0][0]
# __________________________________________________________________________________________________
# tf.reshape_19 (TFOpLambda)      (None, 2028, 85)     0           conv_93[0][0]
# __________________________________________________________________________________________________
# conv_105 (Conv2D)               (None, 52, 52, 255)  65535       leaky_104[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_72 (Sl (None, 507, 2)       0           tf.reshape_18[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_76 (Sl (None, 2028, 2)      0           tf.reshape_19[0][0]
# __________________________________________________________________________________________________
# tf.reshape_20 (TFOpLambda)      (None, 8112, 85)     0           conv_105[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_54 (TFOpLambda) (None, 507, 2)       0           tf.__operators__.getitem_72[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_73 (Sl (None, 507, 2)       0           tf.reshape_18[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_57 (TFOpLambda) (None, 2028, 2)      0           tf.__operators__.getitem_76[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_77 (Sl (None, 2028, 2)      0           tf.reshape_19[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_80 (Sl (None, 8112, 2)      0           tf.reshape_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_179 (TFOpL (None, 507, 2)       0           tf.math.sigmoid_54[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_18 (TFOpLambda)     (None, 507, 2)       0           tf.__operators__.getitem_73[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_74 (Sl (None, 507, 1)       0           tf.reshape_18[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_75 (Sl (None, 507, 80)      0           tf.reshape_18[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_180 (TFOpL (None, 2028, 2)      0           tf.math.sigmoid_57[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_19 (TFOpLambda)     (None, 2028, 2)      0           tf.__operators__.getitem_77[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_78 (Sl (None, 2028, 1)      0           tf.reshape_19[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_79 (Sl (None, 2028, 80)     0           tf.reshape_19[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_60 (TFOpLambda) (None, 8112, 2)      0           tf.__operators__.getitem_80[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_81 (Sl (None, 8112, 2)      0           tf.reshape_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_37 (TFOpLambda (None, 507, 2)       0           tf.__operators__.add_179[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_36 (TFOpLambda (None, 507, 2)       0           tf.math.exp_18[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_55 (TFOpLambda) (None, 507, 1)       0           tf.__operators__.getitem_74[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_56 (TFOpLambda) (None, 507, 80)      0           tf.__operators__.getitem_75[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_39 (TFOpLambda (None, 2028, 2)      0           tf.__operators__.add_180[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_38 (TFOpLambda (None, 2028, 2)      0           tf.math.exp_19[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_58 (TFOpLambda) (None, 2028, 1)      0           tf.__operators__.getitem_78[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_59 (TFOpLambda) (None, 2028, 80)     0           tf.__operators__.getitem_79[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_181 (TFOpL (None, 8112, 2)      0           tf.math.sigmoid_60[0][0]
# __________________________________________________________________________________________________
# tf.math.exp_20 (TFOpLambda)     (None, 8112, 2)      0           tf.__operators__.getitem_81[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_82 (Sl (None, 8112, 1)      0           tf.reshape_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_83 (Sl (None, 8112, 80)     0           tf.reshape_20[0][0]
# __________________________________________________________________________________________________
# tf.concat_42 (TFOpLambda)       (None, 507, 85)      0           tf.math.multiply_37[0][0]
#                                                                  tf.math.multiply_36[0][0]
#                                                                  tf.math.sigmoid_55[0][0]
#                                                                  tf.math.sigmoid_56[0][0]
# __________________________________________________________________________________________________
# tf.concat_44 (TFOpLambda)       (None, 2028, 85)     0           tf.math.multiply_39[0][0]
#                                                                  tf.math.multiply_38[0][0]
#                                                                  tf.math.sigmoid_58[0][0]
#                                                                  tf.math.sigmoid_59[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_41 (TFOpLambda (None, 8112, 2)      0           tf.__operators__.add_181[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_40 (TFOpLambda (None, 8112, 2)      0           tf.math.exp_20[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_61 (TFOpLambda) (None, 8112, 1)      0           tf.__operators__.getitem_82[0][0]
# __________________________________________________________________________________________________
# tf.math.sigmoid_62 (TFOpLambda) (None, 8112, 80)     0           tf.__operators__.getitem_83[0][0]
# __________________________________________________________________________________________________
# tf.concat_45 (TFOpLambda)       (None, 2535, 85)     0           tf.concat_42[0][0]
#                                                                  tf.concat_44[0][0]
# __________________________________________________________________________________________________
# tf.concat_47 (TFOpLambda)       (None, 8112, 85)     0           tf.math.multiply_41[0][0]
#                                                                  tf.math.multiply_40[0][0]
#                                                                  tf.math.sigmoid_61[0][0]
#                                                                  tf.math.sigmoid_62[0][0]
# __________________________________________________________________________________________________
# tf.concat_48 (TFOpLambda)       (None, 10647, 85)    0           tf.concat_45[0][0]
#                                                                  tf.concat_47[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________

# %% [markdown]
# ##requires opencv2 to show
# import cv2
# import time
#
#
# def non_max_suppression(inputs, model_size, max_output_size,
#                         max_output_size_per_class, iou_threshold,
#                         confidence_threshold):
#     bbox, confs, class_probs = tf.split(inputs, [4, 1, -1], axis=-1)
#     bbox=bbox/model_size[0]
#     scores = confs * class_probs
#     boxes, scores, classes, valid_detections = \
#         tf.image.combined_non_max_suppression(
#         boxes=tf.reshape(bbox, (tf.shape(bbox)[0], -1, 1, 4)),
#         scores=tf.reshape(scores, (tf.shape(scores)[0], -1,
#                                    tf.shape(scores)[-1])),
#         max_output_size_per_class=max_output_size_per_class,
#         max_total_size=max_output_size,
#         iou_threshold=iou_threshold,
#         score_threshold=confidence_threshold
#     )
#     return boxes, scores, classes, valid_detections
# def resize_image(inputs, modelsize):
#     inputs= tf.image.resize(inputs, modelsize)
#     return inputs
# def load_class_names(file_name):
#     with open(file_name, 'r') as f:
#         class_names = f.read().splitlines()
#     return class_names
# def output_boxes(inputs,model_size, max_output_size, max_output_size_per_class,
#                  iou_threshold, confidence_threshold):
#     center_x, center_y, width, height, confidence, classes = \
#         tf.split(inputs, [1, 1, 1, 1, 1, -1], axis=-1)
#     top_left_x = center_x - width / 2.0
#     top_left_y = center_y - height / 2.0
#     bottom_right_x = center_x + width / 2.0
#     bottom_right_y = center_y + height / 2.0
#     inputs = tf.concat([top_left_x, top_left_y, bottom_right_x,
#                         bottom_right_y, confidence, classes], axis=-1)
#     boxes_dicts = non_max_suppression(inputs, model_size, max_output_size,
#                                       max_output_size_per_class, iou_threshold, confidence_threshold)
#     return boxes_dicts
# def draw_outputs(img, boxes, objectness, classes, nums, class_names):
#     boxes, objectness, classes, nums = boxes[0], objectness[0], classes[0], nums[0]
#     boxes=np.array(boxes)
#     for i in range(nums):
#         x1y1 = tuple((boxes[i,0:2] * [img.shape[1],img.shape[0]]).astype(np.int32))
#         x2y2 = tuple((boxes[i,2:4] * [img.shape[1],img.shape[0]]).astype(np.int32))
#         img = cv2.rectangle(img, (x1y1), (x2y2), (255,0,0), 2)
#         img = cv2.putText(img, '{} {:.4f}'.format(
#             class_names[int(classes[i])], objectness[i]),
#                           (x1y1), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 2)
#     return img

# %% [markdown]
# import tensorflow as tf
# import cv2
# import numpy as np
# from yolov3 import YOLOv3Net
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
# assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
# tf.config.experimental.set_memory_growth(physical_devices[0], True)
# model_size = (416, 416,3)
# num_classes = 80
# class_name = './data/coco.names'
# max_output_size = 40
# max_output_size_per_class= 20
# iou_threshold = 0.5
# confidence_threshold = 0.5
# cfgfile = 'cfg/yolov3.cfg'
# weightfile = 'weights/yolov3_weights.tf'
# img_path = "data/images/test.jpg"
